# %% [markdown]
# ## Link GDL ADM1 to ADM2

# %% [markdown]
# This notebook is used to link ADM2 shapefiles to the ADM1 shapefiles that we have from the Global Data Lab (GDL).
#
# Throughout the paper, we want to be consistent about what our ADM1 observations are. Because ADM2 observations come from a different source, we also need to hierarchialy link GDL ADM1 observations to the ADM2 observations that are available.
#
# Finally, we need to ensure that any ADM2 observations that are approximately the same as an ADM1 observation (due to data quality issues) are not included in any super-resolution tests.

# %%
import os

repo_dir = os.environ.get("REPO_DIR")
data_dir = os.path.join(repo_dir, "data/")

import geopandas as gpd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import os
import sys

import shapely

# %%
gpdf = pd.read_pickle(data_dir + "int/GDL_HDI/HDI_ADM1_shapefile_clean.p").reset_index()

# %%
adm2 = gpd.read_file(data_dir + "raw/geoBoundaries/geoBoundariesCGAZ_ADM2.geojson")

# %% [markdown]
# Quick inspection of the ADM2 raw data:

# %%
adm2s_per_country = adm2.groupby("shapeGroup").count()["geometry"]

# %%
adm2s_per_country[adm2s_per_country > 500] # Ireland has 50,000 ADM2 observations. This is half the dataset...
# Out:
# shapeGroup
# ARG      527
# AUS      559
# BRA     5585
# COL     1122
# CYP      609
# DZA      547
# ESP     8203
# GBR     9120
# HRV      556
# IDN      518
# IND      641
# IRL    50374
# JPN     1732
# MEX     2458
# NGA      773
# ROU     3235
# RUS     2322
# THA      928
# TUR      969
# UKR      680
# USA     3232
# VNM      774
# Name: geometry, dtype: int64

# %% [markdown]
# ## First, we illustrate the concepual goal with one country (Ethiopia)

# %%
country_code = "ETH"

# %%
adm1_subset = gpdf[gpdf["iso_code"] == country_code]
adm2_subset = adm2[adm2["shapeGroup"] == country_code]

# %% [markdown]
#  We want to match adm2 polygons to their parents (from another source)

# %%
fig, ax = plt.subplots(1,2, figsize=(15,10))

adm1_subset.plot(ax=ax[0])
adm2_subset.plot(ax=ax[1])
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Run an example

# %%
def get_adm1_adm2_intersection_for_country(country_code, adm1=gpdf, adm2=adm2):
    
    """
    This function takes the two polygons and calculates the overlap, including the % overlap. 
    
    It returns a merged geodataframe object
    
    """
    adm1_subset = adm1[adm1["iso_code"] == country_code]
    adm2_subset = adm2[adm2["shapeGroup"] == country_code]
    
    overlaps_list = []
    percentages_list = []
    for adm2_geometry in adm2_subset["geometry"]:
        bools = adm1_subset.intersects(adm2_geometry)
        overlaps = list(adm1_subset["GDLCODE"].loc[bools])
        percentages = list(adm1_subset.loc[bools].intersection(adm2_geometry).area / adm2_geometry.area)

        overlaps_list.append(overlaps)
        percentages_list.append(percentages)

    adm2_subset_copy = adm2_subset.copy()
    adm2_subset_copy["overlaps"] = overlaps_list
    adm2_subset_copy["percent_overlaps"] = percentages_list
    
    return adm2_subset_copy

# %%
example = get_adm1_adm2_intersection_for_country("ETH")
example.head()
# Out:
# /home/lsherman/miniconda3/envs/hdi/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   app.launch_new_instance()
# /home/lsherman/miniconda3/envs/hdi/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   app.launch_new_instance()
# /home/lsherman/miniconda3/envs/hdi/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   app.launch_new_instance()
# /home/lsherman/miniconda3/envs/hdi/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   app.launch_new_instance()
# /home/lsherman/miniconda3/envs/hdi/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   app.launch_new_instance()
# /home/lsherman/miniconda3/envs/hdi/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   app.launch_new_instance()
# /home/lsherman/miniconda3/envs/hdi/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   app.launch_new_instance()
# /home/lsherman/miniconda3/envs/hdi/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   app.launch_new_instance()
# /home/lsherman/miniconda3/envs/hdi/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   app.launch_new_instance()
# /home/lsherman/miniconda3/envs/hdi/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   app.launch_new_instance()
# /home/lsherman/miniconda3/envs/hdi/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   app.launch_new_instance()
# /home/lsherman/miniconda3/envs/hdi/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   app.launch_new_instance()
# /home/lsherman/miniconda3/envs/hdi/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   app.launch_new_instance()
# /home/lsherman/miniconda3/envs/hdi/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   app.launch_new_instance()
# /home/lsherman/miniconda3/envs/hdi/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   app.launch_new_instance()
# /home/lsherman/miniconda3/envs/hdi/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   app.launch_new_instance()
# /home/lsherman/miniconda3/envs/hdi/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   app.launch_new_instance()
# /home/lsherman/miniconda3/envs/hdi/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   app.launch_new_instance()
# /home/lsherman/miniconda3/envs/hdi/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   app.launch_new_instance()
# /home/lsherman/miniconda3/envs/hdi/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   app.launch_new_instance()
# /home/lsherman/miniconda3/envs/hdi/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   app.launch_new_instance()
# /home/lsherman/miniconda3/envs/hdi/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   app.launch_new_instance()
# /home/lsherman/miniconda3/envs/hdi/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   app.launch_new_instance()
# /home/lsherman/miniconda3/envs/hdi/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   app.launch_new_instance()
# /home/lsherman/miniconda3/envs/hdi/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   app.launch_new_instance()
# /home/lsherman/miniconda3/envs/hdi/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   app.launch_new_instance()
# /home/lsherman/miniconda3/envs/hdi/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   app.launch_new_instance()
# /home/lsherman/miniconda3/envs/hdi/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   app.launch_new_instance()
# /home/lsherman/miniconda3/envs/hdi/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   app.launch_new_instance()
# /home/lsherman/miniconda3/envs/hdi/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   app.launch_new_instance()
# /home/lsherman/miniconda3/envs/hdi/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   app.launch_new_instance()
# /home/lsherman/miniconda3/envs/hdi/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   app.launch_new_instance()
# /home/lsherman/miniconda3/envs/hdi/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   app.launch_new_instance()
# /home/lsherman/miniconda3/envs/hdi/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   app.launch_new_instance()
# /home/lsherman/miniconda3/envs/hdi/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   app.launch_new_instance()
# /home/lsherman/miniconda3/envs/hdi/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   app.launch_new_instance()
# /home/lsherman/miniconda3/envs/hdi/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   app.launch_new_instance()
# /home/lsherman/miniconda3/envs/hdi/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   app.launch_new_instance()
# /home/lsherman/miniconda3/envs/hdi/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   app.launch_new_instance()
# /home/lsherman/miniconda3/envs/hdi/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   app.launch_new_instance()
# /home/lsherman/miniconda3/envs/hdi/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   app.launch_new_instance()
# /home/lsherman/miniconda3/envs/hdi/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   app.launch_new_instance()
# /home/lsherman/miniconda3/envs/hdi/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   app.launch_new_instance()
# /home/lsherman/miniconda3/envs/hdi/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   app.launch_new_instance()
# /home/lsherman/miniconda3/envs/hdi/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   app.launch_new_instance()
# /home/lsherman/miniconda3/envs/hdi/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   app.launch_new_instance()
# /home/lsherman/miniconda3/envs/hdi/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   app.launch_new_instance()
# /home/lsherman/miniconda3/envs/hdi/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   app.launch_new_instance()
# /home/lsherman/miniconda3/envs/hdi/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   app.launch_new_instance()
# /home/lsherman/miniconda3/envs/hdi/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   app.launch_new_instance()
# /home/lsherman/miniconda3/envs/hdi/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   app.launch_new_instance()
# /home/lsherman/miniconda3/envs/hdi/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   app.launch_new_instance()
# /home/lsherman/miniconda3/envs/hdi/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   app.launch_new_instance()
# /home/lsherman/miniconda3/envs/hdi/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   app.launch_new_instance()
# /home/lsherman/miniconda3/envs/hdi/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   app.launch_new_instance()
# /home/lsherman/miniconda3/envs/hdi/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   app.launch_new_instance()
# /home/lsherman/miniconda3/envs/hdi/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   app.launch_new_instance()
# /home/lsherman/miniconda3/envs/hdi/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   app.launch_new_instance()
# /home/lsherman/miniconda3/envs/hdi/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   app.launch_new_instance()
# /home/lsherman/miniconda3/envs/hdi/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   app.launch_new_instance()
# /home/lsherman/miniconda3/envs/hdi/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   app.launch_new_instance()
# /home/lsherman/miniconda3/envs/hdi/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   app.launch_new_instance()
# /home/lsherman/miniconda3/envs/hdi/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   app.launch_new_instance()
# /home/lsherman/miniconda3/envs/hdi/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   app.launch_new_instance()
# /home/lsherman/miniconda3/envs/hdi/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   app.launch_new_instance()
# /home/lsherman/miniconda3/envs/hdi/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   app.launch_new_instance()
# /home/lsherman/miniconda3/envs/hdi/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   app.launch_new_instance()
# /home/lsherman/miniconda3/envs/hdi/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   app.launch_new_instance()
# /home/lsherman/miniconda3/envs/hdi/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   app.launch_new_instance()
# /home/lsherman/miniconda3/envs/hdi/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   app.launch_new_instance()
# /home/lsherman/miniconda3/envs/hdi/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   app.launch_new_instance()
# /home/lsherman/miniconda3/envs/hdi/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   app.launch_new_instance()
# /home/lsherman/miniconda3/envs/hdi/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   app.launch_new_instance()
# /home/lsherman/miniconda3/envs/hdi/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: Geometry is in a geographic CRS. Results from 'area' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   app.launch_new_instance()
#        shapeName shapeISO            shapeID shapeGroup shapeType  \
# 112663     Afder     None  ETH-ADM2-3_0_0-B1        ETH      ADM2
# 112664    Agnuak     None  ETH-ADM2-3_0_0-B2        ETH      ADM2
# 112665     Alaba     None  ETH-ADM2-3_0_0-B3        ETH      ADM2
# 112666      Arsi     None  ETH-ADM2-3_0_0-B4        ETH      ADM2
# 112667     Asosa     None  ETH-ADM2-3_0_0-B5        ETH      ADM2
#
#               ADM1_shapeID       ADM0_shapeID  \
# 112663  ETH-ADM1-3_0_0-B10  ETH-ADM0-3_0_0-B1
# 112664   ETH-ADM1-3_0_0-B6  ETH-ADM0-3_0_0-B1
# 112665   ETH-ADM1-3_0_0-B9  ETH-ADM0-3_0_0-B1
# 112666   ETH-ADM1-3_0_0-B8  ETH-ADM0-3_0_0-B1
# 112667   ETH-ADM1-3_0_0-B4  ETH-ADM0-3_0_0-B1
#
#                                              ADMHIERARCHY  \
# 112663  ETH-ADM2-3_0_0-B1|ETH-ADM1-3_0_0-B10|ETH-ADM0-...
# 112664  ETH-ADM2-3_0_0-B2|ETH-ADM1-3_0_0-B6|ETH-ADM0-3...
# 112665  ETH-ADM2-3_0_0-B3|ETH-ADM1-3_0_0-B9|ETH-ADM0-3...
# 112666  ETH-ADM2-3_0_0-B4|ETH-ADM1-3_0_0-B8|ETH-ADM0-3...
# 112667  ETH-ADM2-3_0_0-B5|ETH-ADM1-3_0_0-B4|ETH-ADM0-3...
#
#                                                  geometry  \
# 112663  MULTIPOLYGON (((42.40114 4.19283, 42.40430 4.1...
# 112664  POLYGON ((34.98539 6.30044, 35.01182 6.28188, ...
# 112665  POLYGON ((38.40149 7.59632, 38.34607 7.61142, ...
# 112666  POLYGON ((40.71691 7.89072, 40.68018 7.89418, ...
# 112667  POLYGON ((34.10672 9.49909, 34.10672 9.49799, ...
#
#                            overlaps  \
# 112663           [ETHr104, ETHr105]
# 112664  [ETHr108, ETHr104, ETHr107]
# 112665           [ETHr104, ETHr107]
# 112666           [ETHr102, ETHr104]
# 112667           [ETHr106, ETHr104]
#
#                                          percent_overlaps
# 112663        [0.0003613776691942412, 0.9978554616266985]
# 112664  [0.9971670442441978, 0.0011880718293839573, 0....
# 112665         [0.0069530320210564375, 0.993046967978945]
# 112666       [1.7293686659870696e-05, 0.9999827063133395]
# 112667         [0.995892173871336, 0.0011718941727993381]

# %% [markdown]
# ## Now we repeat the process for all countries and concetenate the outputs

# %%
country_codes = gpdf["iso_code"].unique()

# %% [markdown]
# This intersection calculation is slow so we comment out and save the intermediate output.

# %%
# dfs = []

# for country_code in country_codes:
#     print(country_code)
#     dfs.append(get_adm1_adm2_intersection_for_country(country_code))
# output_df = pd.concat(dfs)

# %%
int_outpath = data_dir + "int/ADM2_to_GDL_link/int_file_adm2_polygons_linked_to_GDL_adm1.p"
#output_df.to_pickle(int_outpath)

# %%
output_df = pd.read_pickle(int_outpath)

# %%
output_df.head()
# Out:
#          shapeName shapeISO            shapeID shapeGroup shapeType  \
# 1358     Kota Batu     None  BRN-ADM2-3_0_0-B1        BRN      ADM2
# 1359       Kilanas     None  BRN-ADM2-3_0_0-B2        BRN      ADM2
# 1360  Tanjong Maya     None  BRN-ADM2-3_0_0-B3        BRN      ADM2
# 1361        Serasa     None  BRN-ADM2-3_0_0-B4        BRN      ADM2
# 1362       Mentiri     None  BRN-ADM2-3_0_0-B5        BRN      ADM2
#
#            ADM1_shapeID       ADM0_shapeID  \
# 1358  BRN-ADM1-3_0_0-B3  BRN-ADM0-3_0_0-B1
# 1359  BRN-ADM1-3_0_0-B3  BRN-ADM0-3_0_0-B1
# 1360  BRN-ADM1-3_0_0-B4  BRN-ADM0-3_0_0-B1
# 1361  BRN-ADM1-3_0_0-B3  BRN-ADM0-3_0_0-B1
# 1362  BRN-ADM1-3_0_0-B3  BRN-ADM0-3_0_0-B1
#
#                                            ADMHIERARCHY  \
# 1358  BRN-ADM2-3_0_0-B1|BRN-ADM1-3_0_0-B3|BRN-ADM0-3...
# 1359  BRN-ADM2-3_0_0-B2|BRN-ADM1-3_0_0-B3|BRN-ADM0-3...
# 1360  BRN-ADM2-3_0_0-B3|BRN-ADM1-3_0_0-B4|BRN-ADM0-3...
# 1361  BRN-ADM2-3_0_0-B4|BRN-ADM1-3_0_0-B3|BRN-ADM0-3...
# 1362  BRN-ADM2-3_0_0-B5|BRN-ADM1-3_0_0-B3|BRN-ADM0-3...
#
#                                                geometry overlaps  \
# 1358  POLYGON ((115.01400 4.93203, 114.99643 4.94485...   [BRNt]
# 1359  POLYGON ((114.90051 4.87061, 114.87530 4.86444...   [BRNt]
# 1360  POLYGON ((114.70729 4.75307, 114.66990 4.78399...   [BRNt]
# 1361  POLYGON ((115.04237 4.96770, 115.04136 4.97294...   [BRNt]
# 1362  POLYGON ((115.01400 4.93203, 115.01859 4.93775...   [BRNt]
#
#           percent_overlaps
# 1358  [0.8699735723270333]
# 1359  [1.0000000000000002]
# 1360                 [1.0]
# 1361  [0.9611905164358165]
# 1362  [0.9923242896225124]

# %% [markdown]
# ### Now we are going to do further processing before we finalize the linking

# %%
def max_overlap(x):
    if x  == []:
        return None
    else:
        return max(x)

# %%
overlap_dist = (output_df["percent_overlaps"].apply(max_overlap))

# %% [markdown]
# Visually inspect the max percent overlap of the ADM2 polygons. This looks quite good

# %%
overlap_dist.hist()
plt.title("ADM2 obs overlap perc with ADM1 obs")
# Out:
# Text(0.5, 1.0, 'ADM2 obs overlap perc with ADM1 obs')

# %% [markdown]
# ### Based on this data, we are going to drop ADM2 polygons that have less than 50% intersection with the GDL ADM1 polygons.
# For these, we can't be sure that we are matching correctly.

# %%
print("Dropped ADM2 observations -- because there is no intersection or intersection is less than 50% of the adm2 area:")
drop_count = np.isnan(overlap_dist).sum() + (overlap_dist < .5).sum()
print(drop_count)
print("\n")

print(f"We are dropping {round(drop_count/len(adm2) * 100,2)}% of the ADM2 observations")
# Out:
# Dropped ADM2 observations -- because there is no intersection or intersection is less than 50% of the adm2 area:
# 461
#
#
# We are dropping 0.41% of the ADM2 observations

# %%
keep_idxs = ~(np.isnan(overlap_dist) | (overlap_dist < .3))
output_df_drop = output_df.copy()[keep_idxs]

# %%
arg_maxes = output_df_drop["percent_overlaps"].apply(np.argmax)

# %%
output_df_drop.head()
# Out:
#          shapeName shapeISO            shapeID shapeGroup shapeType  \
# 1358     Kota Batu     None  BRN-ADM2-3_0_0-B1        BRN      ADM2
# 1359       Kilanas     None  BRN-ADM2-3_0_0-B2        BRN      ADM2
# 1360  Tanjong Maya     None  BRN-ADM2-3_0_0-B3        BRN      ADM2
# 1361        Serasa     None  BRN-ADM2-3_0_0-B4        BRN      ADM2
# 1362       Mentiri     None  BRN-ADM2-3_0_0-B5        BRN      ADM2
#
#            ADM1_shapeID       ADM0_shapeID  \
# 1358  BRN-ADM1-3_0_0-B3  BRN-ADM0-3_0_0-B1
# 1359  BRN-ADM1-3_0_0-B3  BRN-ADM0-3_0_0-B1
# 1360  BRN-ADM1-3_0_0-B4  BRN-ADM0-3_0_0-B1
# 1361  BRN-ADM1-3_0_0-B3  BRN-ADM0-3_0_0-B1
# 1362  BRN-ADM1-3_0_0-B3  BRN-ADM0-3_0_0-B1
#
#                                            ADMHIERARCHY  \
# 1358  BRN-ADM2-3_0_0-B1|BRN-ADM1-3_0_0-B3|BRN-ADM0-3...
# 1359  BRN-ADM2-3_0_0-B2|BRN-ADM1-3_0_0-B3|BRN-ADM0-3...
# 1360  BRN-ADM2-3_0_0-B3|BRN-ADM1-3_0_0-B4|BRN-ADM0-3...
# 1361  BRN-ADM2-3_0_0-B4|BRN-ADM1-3_0_0-B3|BRN-ADM0-3...
# 1362  BRN-ADM2-3_0_0-B5|BRN-ADM1-3_0_0-B3|BRN-ADM0-3...
#
#                                                geometry overlaps  \
# 1358  POLYGON ((115.01400 4.93203, 114.99643 4.94485...   [BRNt]
# 1359  POLYGON ((114.90051 4.87061, 114.87530 4.86444...   [BRNt]
# 1360  POLYGON ((114.70729 4.75307, 114.66990 4.78399...   [BRNt]
# 1361  POLYGON ((115.04237 4.96770, 115.04136 4.97294...   [BRNt]
# 1362  POLYGON ((115.01400 4.93203, 115.01859 4.93775...   [BRNt]
#
#           percent_overlaps
# 1358  [0.8699735723270333]
# 1359  [1.0000000000000002]
# 1360                 [1.0]
# 1361  [0.9611905164358165]
# 1362  [0.9923242896225124]

# %%
final_overlap_percentages = [output_df_drop["percent_overlaps"].iloc[i][item] for i,item in enumerate(arg_maxes)]
final_overlap_adm1 = [output_df_drop["overlaps"].iloc[i][item] for i,item in enumerate(arg_maxes)]

# %%
final_adm2_process = output_df_drop.drop(["overlaps", "percent_overlaps"], axis=1)

# %%
final_adm2_process["GDL_ADM1"] = final_overlap_adm1
final_adm2_process["percent_overlap_GDL_ADM1"] = np.round(np.array(final_overlap_percentages)*100,2)

# %%
final_adm2_process.head()
# Out:
#          shapeName shapeISO            shapeID shapeGroup shapeType  \
# 1358     Kota Batu     None  BRN-ADM2-3_0_0-B1        BRN      ADM2
# 1359       Kilanas     None  BRN-ADM2-3_0_0-B2        BRN      ADM2
# 1360  Tanjong Maya     None  BRN-ADM2-3_0_0-B3        BRN      ADM2
# 1361        Serasa     None  BRN-ADM2-3_0_0-B4        BRN      ADM2
# 1362       Mentiri     None  BRN-ADM2-3_0_0-B5        BRN      ADM2
#
#            ADM1_shapeID       ADM0_shapeID  \
# 1358  BRN-ADM1-3_0_0-B3  BRN-ADM0-3_0_0-B1
# 1359  BRN-ADM1-3_0_0-B3  BRN-ADM0-3_0_0-B1
# 1360  BRN-ADM1-3_0_0-B4  BRN-ADM0-3_0_0-B1
# 1361  BRN-ADM1-3_0_0-B3  BRN-ADM0-3_0_0-B1
# 1362  BRN-ADM1-3_0_0-B3  BRN-ADM0-3_0_0-B1
#
#                                            ADMHIERARCHY  \
# 1358  BRN-ADM2-3_0_0-B1|BRN-ADM1-3_0_0-B3|BRN-ADM0-3...
# 1359  BRN-ADM2-3_0_0-B2|BRN-ADM1-3_0_0-B3|BRN-ADM0-3...
# 1360  BRN-ADM2-3_0_0-B3|BRN-ADM1-3_0_0-B4|BRN-ADM0-3...
# 1361  BRN-ADM2-3_0_0-B4|BRN-ADM1-3_0_0-B3|BRN-ADM0-3...
# 1362  BRN-ADM2-3_0_0-B5|BRN-ADM1-3_0_0-B3|BRN-ADM0-3...
#
#                                                geometry GDL_ADM1  \
# 1358  POLYGON ((115.01400 4.93203, 114.99643 4.94485...     BRNt
# 1359  POLYGON ((114.90051 4.87061, 114.87530 4.86444...     BRNt
# 1360  POLYGON ((114.70729 4.75307, 114.66990 4.78399...     BRNt
# 1361  POLYGON ((115.04237 4.96770, 115.04136 4.97294...     BRNt
# 1362  POLYGON ((115.01400 4.93203, 115.01859 4.93775...     BRNt
#
#       percent_overlap_GDL_ADM1
# 1358                     87.00
# 1359                    100.00
# 1360                    100.00
# 1361                     96.12
# 1362                     99.23

# %% [markdown]
# ### Check that no polygons are getting the wrong country assigned after this process:

# %%
all(final_adm2_process["shapeGroup"] == final_adm2_process["GDL_ADM1"].apply(lambda x: x[:3]))
# Out:
# True

# %% [markdown]
# ### One last check -- see if ADM1 polygon has only 1 ADM2 observation

# %%
adm2s_per_adm1 = final_adm2_process.groupby("GDL_ADM1").count()["shapeName"]

# %%
adm2s_per_adm1.sort_values(ascending=False).head(20)
# Out:
# GDL_ADM1
# IRLr101    9832
# IRLr103    9548
# IRLr107    9280
# IRLr108    7970
# IRLr102    4440
# IRLr106    4239
# IRLr105    4034
# ESPr109    2298
# GBRr108    1408
# GBRr106    1057
# IRLr104    1004
# GBRr109     998
# ESPr112     948
# ESPr110     921
# GBRr102     921
# GBRr104     882
# BRAr117     852
# GBRr110     850
# ESPr115     779
# GBRr105     744
# Name: shapeName, dtype: int64

# %%
adm2s_per_adm1.hist()
plt.title("ADM2 obs per ADM1")
# Out:
# Text(0.5, 1.0, 'ADM2 obs per ADM1')

# %%
single_adm2 = (adm2s_per_adm1 ==1)
print(f" { single_adm2.sum()} ADM1 observations have a single ADM2 observation")
# Out:
#  107 ADM1 observations have a single ADM2 observation

# %% [markdown]
# This isn't necessarily a problem -- just a phenomenon that we want to be aware of. It's a very small percentage of our ADM2 observations.

# %%
adm1_has_one_adm2 = gpdf.set_index("GDLCODE").loc[single_adm2.index[single_adm2]]
adm1_has_one_adm2.head(15)
# Out:
#          constant iso_code       country                     region      shdi  \
# GDL_ADM1
# ARMr111     World      ARM       Armenia                    Yerevan  0.801494
# AUTr103     World      AUT       Austria                       Wien  0.939604
# AZEr101     World      AZE    Azerbaijan                       Baku  0.821687
# BELr101     World      BEL       Belgium        Bruxelles - Brussel  0.946450
# BELr102     World      BEL       Belgium            Prov. Antwerpen  0.930527
# BELr103     World      BEL       Belgium              Prov. Limburg  0.913273
# BELr104     World      BEL       Belgium      Prov. Oost-Vlaanderen  0.920684
# BELr105     World      BEL       Belgium       Prov. Vlaams-Brabant  0.937775
# BELr106     World      BEL       Belgium      Prov. West-Vlaanderen  0.922509
# BELr107     World      BEL       Belgium       Prov. Brabant Wallon  0.924734
# BELr108     World      BEL       Belgium              Prov. Hainaut  0.874404
# BELr109     World      BEL       Belgium                Prov. Liege  0.885979
# BELr110     World      BEL       Belgium           Prov. Luxembourg  0.885853
# BELr111     World      BEL       Belgium                Prov. Namur  0.890381
# BFAr103     World      BFA  Burkina Faso  Centre (incl Ouagadougou)  0.620092
#
#                                                    geometry
# GDL_ADM1
# ARMr111   POLYGON ((44.41855 40.21835, 44.41855 40.23283...
# AUTr103   POLYGON ((16.22044 48.13174, 16.23200 48.13318...
# AZEr101   MULTIPOLYGON (((49.58688 40.03549, 49.57696 40...
# BELr101   POLYGON ((4.40336 50.77439, 4.40352 50.77405, ...
# BELr102   MULTIPOLYGON (((4.32708 51.19880, 4.32341 51.2...
# BELr103   MULTIPOLYGON (((5.80529 50.71799, 5.79906 50.7...
# BELr104   POLYGON ((3.67587 50.76648, 3.67325 50.76197, ...
# BELr105   POLYGON ((5.05329 50.72244, 5.05450 50.72420, ...
# BELr106   MULTIPOLYGON (((2.92501 50.76250, 2.92090 50.7...
# BELr107   POLYGON ((4.18120 50.65783, 4.16517 50.64738, ...
# BELr108   MULTIPOLYGON (((3.73450 50.33233, 3.73112 50.3...
# BELr109   POLYGON ((5.41822 50.42754, 5.41837 50.42286, ...
# BELr110   POLYGON ((5.53243 49.51296, 5.53146 49.51252, ...
# BELr111   POLYGON ((4.57019 49.97363, 4.56153 49.96983, ...
# BFAr103   POLYGON ((-1.72342 12.09224, -1.73425 12.09201...

# %% [markdown]
# ### Now we write the output file

# %%
outpath = data_dir + "int/ADM2_to_GDL_link/adm2_polygons_linked_to_GDL_adm1.p"

# %%
final_adm2_process.to_pickle(outpath)

# %%
final_adm2_process.plot()
# Out:
# <AxesSubplot:>

# %%
final_adm2_process = pd.read_pickle(data_dir + "int/ADM2_to_GDL_link/adm2_polygons_linked_to_GDL_adm1.p")
