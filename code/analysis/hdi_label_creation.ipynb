# %%
import os

repo_dir = os.environ.get("REPO_DIR")
code_dir = os.path.join(repo_dir, "code/")
data_dir = os.path.join(repo_dir, "data/")

os.chdir(code_dir)

import geopandas as gpd
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd

import os

import sys


from mosaiks.label_utils.utils import geopandas_shape_grid, box_grid, assign_grid_points_to_gpdFile, get_dense_grid_for_gpdf_file
from mosaiks.label_utils.plotting_utils import plot_label_map_hist

# %% [markdown]
# # HDI data (Smits et al)
#
# **Data Download:**
#
# *Shapefiles and tabular data are separate downloads*
#
# Tabular data:
# https://globaldatalab.org/mygdl/downloads/
#
# We are using the SHDI V4 data in this analysis. Version history is [here](https://globaldatalab.org/shdi/archive/).
#
#
# Shapefiles:
# https://globaldatalab.org/shdi/shapefiles/
#
# We use the neweset shapefile available when this project began `GDL Shapefiles V4`. This file is NOT included in the GitHub repository and must be downloaded to replicate our data cleaning.
#
#
#
# **Data Citation**
#
# Smits, J., Permanyer, I. The Subnational Human Development Database. Sci Data 6, 190038 (2019). https://doi.org/10.1038/sdata.2019.38
#
# **Corresponding paper:**
#
# https://www.nature.com/articles/sdata201938
#
#
# **Abstract**
#
# In this paper we describe the Subnational Human Development Database. This database contains for the period 1990–2017 for 1625 regions within 161 countries the national and subnational values of the Subnational Human Development Index (SHDI), for the three dimension indices on the basis of which the SHDI is constructed – education, health and standard of living --, and for the four indicators needed to create the dimension indices -- expected years of schooling, mean years of schooling, life expectancy and gross national income per capita. The subnational values of the four indicators were computed using data from statistical offices and from the Area Database of the Global Data Lab, which contains indicators aggregated from household surveys and census datasets. Values for missing years were estimated by interpolation and extrapolation from real data. By normalizing the population-weighted averages of the indicators to their national levels in the UNDP-HDI database, values of the SHDI and its dimension indices were obtained that at national level equal their official versions of the UNDP.
#
#
# **Data sources**
#
# Three major data sources were used to create our SHDI database. We approached statistical offices, including Eurostat, the statistical office of the European Union (https://ec.europa.eu/eurostat), by email communication or visiting their websites to obtain data. We downloaded data from the Area Database of the Global Data Lab (https://www.globaldatalab.org). And we downloaded data from the HDI website of the Human Development Report Office of the United Nations Development Program (http://hdr.undp.org). In the ‘SHDI Start’ data file (Data Citation 1), for each country information is provided on the data source(s) used for the subnational values of the indicators. In this file also for each country the years for which data is available, the number of subnational regions and the population size is presented. Below we discuss the three main data sources in more detail.
#
# **Local paths**
#
# Tabular data:
#
# `/raw/GDL_HDI/GDL-Indicators-(2018)-data.csv`
#
# `raw/GDL_HDI/GDL-Indices-(2018)-data.csv`
#
# Shapefiles:
#
# `raw/GDL_HDI/GDL_Shapefiles_V4`

# %% [markdown]
# ## Read in shape files

# %%
directory = data_dir + "/raw/GDL_HDI/"
out_directory = data_dir + "/int/GDL_HDI/"

## This file MUST be downloaded from the link above, unzipped, and placed in the correct subdirectory
gpdf = gpd.read_file(directory+"GDL_Shapefiles_V4/GDL_Shapefiles_V4.shp")

# %%
len(gpdf)
# Out:
# 1745

# %%
gpdf.set_index("GDLcode", inplace=True)
gpdf.loc["BHRt","iso_code"] = "BHR" # Fix weird anomaly in shapefile
gpdf.loc["MLTt","iso_code"] = "MLT" # Fix weird anomaly in shapefile
gpdf.reset_index(inplace=True)
gpdf.dropna(subset = ["GDLcode"], inplace=True) #Drop weird NAs in GDLcode column

# %% [markdown]
# ### Let's make and save a country aggregated version of this shapefiile -- it will be useful later

# %%
#gpdf_country = gpdf.dissolve("iso_code")

# %%
#gpdf_country.to_pickle(out_directory + "/HDI_ADM0_dissolved_shapefile.p")

# %% [markdown]
# ## Read and clean data files
#
# The data includes a set of indicator variables and a set of indices. First we will merge these dataframes.
#
# The data also come with a column of national indicators. We drop these when we have subnational data for a country.

# %% [markdown]
# [If we decide to update with newer data, use code that is commented out in this markdown cell]
#
# <!-- # data = pd.read_csv(directory + "SHDI-SGDI-Total 5.0.csv", low_memory=False)
# # data = data[data["year"] == 2019].copy()
# # rename_dictionary = {"shdi" : "Sub-national HDI",
# #                     "msch": "Mean years schooling",
# #                     "esch":"Expected years schooling",
# #                     "lifexp":"Life expectancy",
# #                     "gnic": "GNI per capita in thousands of US$ (2011 PPP)" }
#
# # data.rename(columns = rename_dictionary, inplace=True)
#
# # unneeded_cols = ['sgdi', 'shdif', 'shdim',
# #        'healthindex', 'healthindexf', 'healthindexm', 'incindex', 'incindexf',
# #        'incindexm', 'edindex', 'edindexf', 'edindexm', 'eschf',
# #        'eschm', 'mschf', 'mschm', 'gnicf',
# #        'gnicm',  'mfsel', "lgnic", "lgnicf", "lgnicm", "lifexpf", "lifexpm"]
#
# # data.drop(unneeded_cols, inplace=True)
#  -->

# %%
indicators = pd.read_csv(directory + 'GDL-Indicators-(2018)-data.csv')
indices =  pd.read_csv(directory + 'GDL-Indices-(2018)-data.csv')

# %%
data = pd.concat([indicators, indices.iloc[:,5:]], axis=1) # Merge indices and indicators so we have both

# %%
## Now we want to take the countries where we only have national data and merge those with the dataframe of subnational entities
national_data_only_indices = data.groupby("ISO_Code").count()["Country"]==1
national_data_only = data.groupby("ISO_Code").first()[national_data_only_indices].reset_index()

subnational_data_only = data[data["Region"] != "Total"]

df = pd.concat([national_data_only, subnational_data_only])

# %% [markdown]
# ### Let's inspect the set of countries that do not have subnational province observations

# %%
#pd.set_option('display.max_rows', None)
print("Countries that do not have ADM1 child regions:")
national_data_only
# Out:
# Countries that do not have ADM1 child regions:
#    ISO_Code                           Country     Level GDLCODE Region  \
# 0       AND                           Andorra  National    ANDt  Total
# 1       ARE              United Arab Emirates  National    AREt  Total
# 2       ATG               Antigua and Barbuda  National    ATGt  Total
# 3       BHR                           Bahrain  National    BHRt  Total
# 4       BHS                           Bahamas  National    BHSt  Total
# 5       BRN                 Brunei Darussalam  National    BRNt  Total
# 6       CYP                            Cyprus  National    CYPt  Total
# 7       DMA                          Dominica  National    DMAt  Total
# 8       FSM  Micronesia (Federated States of)  National    FSMt  Total
# 9       GRD                           Grenada  National    GRDt  Total
# 10      ISL                           Iceland  National    ISLt  Total
# 11      ISR                            Israel  National    ISRt  Total
# 12      KIR                          Kiribati  National    KIRt  Total
# 13      KNA             Saint Kitts and Nevis  National     KNA  Total
# 14      LCA                       Saint Lucia  National    LCAt  Total
# 15      LIE                     Liechtenstein  National    LIEt  Total
# 16      LKA                         Sri Lanka  National    LKAt  Total
# 17      LUX                        Luxembourg  National    LUXt  Total
# 18      OMN                              Oman  National    OMNt  Total
# 19      QAT                             Qatar  National    QATt  Total
# 20      SGP                         Singapore  National    SGPt  Total
# 21      SLB                   Solomon Islands  National    SLBt  Total
# 22      TON                             Tonga  National    TONt  Total
# 23      VCT  Saint Vincent and the Grenadines  National    VCTt  Total
# 24      WSM                             Samoa  National    WSMt  Total
#
#     Life expectancy  GNI per capita in thousands of US$ (2011 PPP)  \
# 0             81.79                                         48.640
# 1             77.81                                         66.910
# 2             76.89                                         22.200
# 3             77.16                                         40.400
# 4             73.75                                         28.400
# 5             75.72                                         76.390
# 6             80.83                                         33.100
# 7             78.12                                          9.245
# 8             67.76                                          3.700
# 9             72.38                                         12.680
# 10            82.86                                         47.570
# 11            82.82                                         33.650
# 12            68.12                                          3.917
# 13            74.56                                         26.770
# 14            76.06                                         11.530
# 15            80.54                                         99.730
# 16            76.81                                         11.610
# 17            82.10                                         65.540
# 18            77.63                                         37.040
# 19            80.10                                        110.500
# 20            83.46                                         83.790
# 21            72.84                                          2.027
# 22            70.80                                          5.783
# 23            72.42                                         11.750
# 24            73.19                                          5.885
#
#     Expected years schooling  Mean years schooling  \
# 0                       13.3                 10.20
# 1                       13.6                 11.00
# 2                       12.5                  9.26
# 3                       15.3                  9.41
# 4                       12.8                 11.50
# 5                       14.4                  9.10
# 6                       14.7                 12.10
# 7                       13.0                  7.80
# 8                       11.6                  7.72
# 9                       16.6                  8.80
# 10                      19.2                 12.50
# 11                      16.0                 13.00
# 12                      11.8                  7.87
# 13                      13.6                  8.50
# 14                      13.9                  8.49
# 15                      14.7                 12.60
# 16                      14.0                 11.10
# 17                      14.2                 12.20
# 18                      14.7                  9.73
# 19                      12.2                  9.67
# 20                      16.3                 11.50
# 21                      10.2                  5.54
# 22                      14.3                 11.20
# 23                      13.6                  8.62
# 24                      12.5                 10.60
#
#     Population size in millions  Sub-national HDI  Health index  Income index  \
# 0                          0.08             0.857         0.951         0.935
# 1                          9.63             0.866         0.889         0.983
# 2                          0.10             0.776         0.875         0.816
# 3                          1.57             0.838         0.879         0.907
# 4                          0.39             0.805         0.827         0.853
# 5                          0.43             0.845         0.857         1.000
# 6                          1.19             0.873         0.936         0.876
# 7                          0.07             0.724         0.894         0.684
# 8                          0.11             0.614         0.735         0.545
# 9                          0.11             0.763         0.806         0.732
# 10                         0.35             0.938         0.967         0.931
# 11                         8.88             0.906         0.966         0.879
# 12                         0.12             0.623         0.740         0.554
# 13                         0.05             0.776         0.839         0.844
# 14                         0.18             0.745         0.862         0.717
# 15                         0.04             0.917         0.931         1.000
# 16                        21.70             0.780         0.874         0.718
# 17                         0.61             0.909         0.955         0.980
# 18                         4.83             0.834         0.887         0.893
# 19                         2.78             0.849         0.925         1.000
# 20                         5.64             0.935         0.976         1.000
# 21                         0.65             0.558         0.813         0.455
# 22                         0.10             0.718         0.782         0.613
# 23                         0.11             0.728         0.806         0.720
# 24                         0.20             0.707         0.818         0.616
#
#     Educational index
# 0                0.708
# 1                0.744
# 2                0.655
# 3                0.738
# 4                0.740
# 5                0.703
# 6                0.811
# 7                0.620
# 8                0.578
# 9                0.754
# 10               0.918
# 11               0.876
# 12               0.590
# 13               0.661
# 14               0.668
# 15               0.827
# 16               0.756
# 17               0.802
# 18               0.732
# 19               0.661
# 20               0.837
# 21               0.469
# 22               0.771
# 23               0.664
# 24               0.701

# %% [markdown]
# These are all very small countries and this appears to be reasonable.

# %% [markdown]
# ### The shapefile is not a perfect match the tabular data
#
# Let's analyze what is missing

# %% [markdown]
# #### First, let's inspect the set of countries that cannot be linked to a shapefile primary key

# %%
nats_dropped = national_data_only[~national_data_only["GDLCODE"].isin(gpdf["GDLcode"])]
nats_dropped
# Out:
#    ISO_Code                Country     Level GDLCODE Region  Life expectancy  \
# 12      KIR               Kiribati  National    KIRt  Total            68.12
# 13      KNA  Saint Kitts and Nevis  National     KNA  Total            74.56
# 14      LCA            Saint Lucia  National    LCAt  Total            76.06
#
#     GNI per capita in thousands of US$ (2011 PPP)  Expected years schooling  \
# 12                                          3.917                      11.8
# 13                                         26.770                      13.6
# 14                                         11.530                      13.9
#
#     Mean years schooling  Population size in millions  Sub-national HDI  \
# 12                  7.87                         0.12             0.623
# 13                  8.50                         0.05             0.776
# 14                  8.49                         0.18             0.745
#
#     Health index  Income index  Educational index
# 12         0.740         0.554               0.590
# 13         0.839         0.844               0.661
# 14         0.862         0.717               0.668

# %% [markdown]
# These are very small countries. Excluding these from our analysis seems reasonable.

# %% [markdown]
# #### Second, let's inspect the set of ADM1 polygons that cannot be linked to a shapefile primary key

# %%
subnats_dropped = subnational_data_only[~subnational_data_only.GDLCODE.isin(gpdf.GDLcode)]
subnats_dropped
# Out:
#              Country ISO_Code   Level  GDLCODE  \
# 374            China      CHN  Subnat  CHNr133
# 494   Czech Republic      CZE  Subnat  CZEr101
# 588             Fiji      FJI  Subnat  FJIr108
# 589             Fiji      FJI  Subnat  FJIr106
# 590             Fiji      FJI  Subnat  FJIr105
# 591             Fiji      FJI  Subnat  FJIr107
# 592             Fiji      FJI  Subnat  FJIr109
# 593             Fiji      FJI  Subnat  FJIr101
# 594             Fiji      FJI  Subnat  FJIr110
# 595             Fiji      FJI  Subnat  FJIr102
# 596             Fiji      FJI  Subnat  FJIr103
# 597             Fiji      FJI  Subnat  FJIr104
# 616           France      FRA  Subnat  FRAr125
# 622           France      FRA  Subnat  FRAr126
# 630           France      FRA  Subnat  FRAr128
# 635            Gabon      GAB  Subnat  GABr110
# 924            Italy      ITA  Subnat  ITAr113
# 965       Kazakhstan      KAZ  Subnat  KAZr101
# 982           Kosovo      XKO  Subnat  KSVr107
# 983           Kosovo      XKO  Subnat  KSVr101
# 984           Kosovo      XKO  Subnat  KSVr102
# 985           Kosovo      XKO  Subnat  KSVr103
# 986           Kosovo      XKO  Subnat  KSVr104
# 987           Kosovo      XKO  Subnat  KSVr106
# 988           Kosovo      XKO  Subnat  KSVr105
# 994       Kyrgyzstan      KGZ  Subnat  KGZr108
# 997       Kyrgyzstan      KGZ  Subnat  KGZr105
# 998       Kyrgyzstan      KGZ  Subnat  KGZr107
# 1000      Kyrgyzstan      KGZ  Subnat  KGZr106
# 1023          Latvia      LVA  Subnat  LVAr102
# 1131        Maldives      MDV  Subnat  MDVr104
# 1132        Maldives      MDV  Subnat  MDVr101
# 1133        Maldives      MDV  Subnat  MDVr102
# 1134        Maldives      MDV  Subnat  MDVr103
# 1135        Maldives      MDV  Subnat  MDVr106
# 1136        Maldives      MDV  Subnat  MDVr105
# 1147           Malta      MLT  Subnat  MLTr102
# 1148           Malta      MLT  Subnat  MLTr101
# 1622           Spain      ESP  Subnat  ESPr117
# 1623           Spain      ESP  Subnat  ESPr118
# 1676      Tajikistan      TJK  Subnat  TJKr101
# 1866         Vanuatu      VUT  Subnat  VUTr108
# 1869         Vanuatu      VUT  Subnat  VUTr107
#
#                               Region  Life expectancy  \
# 374                           Taiwan            81.76
# 494                            Praha            80.70
# 588                               Ba            66.02
# 589                  Cakaudrove, Bua            68.71
# 590   Kadavu, Lau, Lomaiviti, Rotuma            67.37
# 591                          Macuata            67.10
# 592                Nadroga or Navosa            68.01
# 593                        Naitasiri            67.80
# 594                               Ra            66.62
# 595                             Rewa            68.26
# 596                    Serua, Namosi            67.17
# 597                          Tailevu            68.61
# 616                       Guadeloupe            81.34
# 622                       Martinique            81.74
# 630                          Reunion            80.65
# 635           Libreville-Port Gentil            67.18
# 924    Provincia Autonoma di Bolzano            84.09
# 965                      Almaty city            71.72
# 982                          Ferizaj            73.75
# 983                          Gjakova            72.07
# 984                           Gjilan            73.40
# 985                        Mitrovica            73.05
# 986                             Peja            69.91
# 987                         Pristina            72.82
# 988                          Prizren            71.17
# 994                           Batken            70.31
# 997                       Jalal-Abad            72.58
# 998                            Naryn            69.82
# 1000                             Osh            70.57
# 1023                  Pieriga region            76.48
# 1131                         Central            78.88
# 1132                            Male            78.28
# 1133                           North            78.40
# 1134                   North Central            79.71
# 1135                           South            78.27
# 1136                   South Central            78.89
# 1147                     Gozo Region            82.38
# 1148                    Malta Region            82.38
# 1622        Ciudad Autonoma de Ceuta            81.37
# 1623      Ciudad Autonoma de Melilla            81.17
# 1676                        Duchanbe            74.37
# 1866                      Luganville            72.73
# 1869                       Port Vila            69.99
#
#       GNI per capita in thousands of US$ (2011 PPP)  Expected years schooling  \
# 374                                          44.440                      16.7
# 494                                          66.640                      21.0
# 588                                          12.100                      14.0
# 589                                           4.335                      13.3
# 590                                           4.209                      14.0
# 591                                           7.913                      14.3
# 592                                           7.139                      13.4
# 593                                          11.500                      15.1
# 594                                           5.037                      13.5
# 595                                          12.520                      15.8
# 596                                           8.708                      13.4
# 597                                           7.517                      15.0
# 616                                          26.050                      14.7
# 622                                          29.160                      15.0
# 630                                          26.990                      14.5
# 635                                          21.550                      13.0
# 924                                          56.170                      14.3
# 965                                          27.610                      16.7
# 982                                          10.260                      14.2
# 983                                          10.620                      13.7
# 984                                           9.379                      14.5
# 985                                          10.080                      14.5
# 986                                          10.040                      14.4
# 987                                          10.880                      14.8
# 988                                          10.000                      13.2
# 994                                           3.203                      11.4
# 997                                           2.868                      12.4
# 998                                           2.781                      13.6
# 1000                                          2.815                      12.6
# 1023                                         20.960                      16.0
# 1131                                         11.170                      10.9
# 1132                                         14.630                      13.0
# 1133                                         11.250                      11.2
# 1134                                         11.240                      10.9
# 1135                                         11.780                      11.4
# 1136                                         11.450                      11.2
# 1147                                         20.420                      15.3
# 1148                                         35.870                      15.9
# 1622                                         27.770                      16.4
# 1623                                         25.370                      16.0
# 1676                                          5.738                      12.1
# 1866                                          5.938                      15.0
# 1869                                          7.760                      13.5
#
#       Mean years schooling  Population size in millions  Sub-national HDI  \
# 374                   9.48                         2.79             0.880
# 494                  14.00                         1.29             0.961
# 588                  10.90                         0.24             0.728
# 589                   9.93                         0.07             0.668
# 590                  10.10                         0.04             0.669
# 591                  10.20                         0.08             0.706
# 592                  10.60                         0.06             0.701
# 593                  11.40                         0.17             0.749
# 594                  10.20                         0.03             0.672
# 595                  11.70                         0.11             0.765
# 596                  11.10                         0.03             0.713
# 597                  11.00                         0.06             0.726
# 616                  10.20                         0.43             0.841
# 622                  10.50                         0.38             0.854
# 630                  10.10                         0.86             0.836
# 635                   9.55                         1.14             0.738
# 924                  10.40                         0.52             0.888
# 965                  13.20                         1.37             0.848
# 982                  11.00                         0.20             0.760
# 983                  10.20                         0.19             0.741
# 984                  10.40                         0.20             0.750
# 985                  11.40                         0.26             0.764
# 986                  10.70                         0.20             0.740
# 987                  11.10                         0.48             0.766
# 988                   9.92                         0.32             0.725
# 994                  10.50                         0.46             0.647
# 997                  10.50                         1.04             0.658
# 998                  10.80                         0.30             0.657
# 1000                 10.40                         1.57             0.649
# 1023                 12.80                         0.36             0.849
# 1131                  5.33                         0.04             0.677
# 1132                  8.32                         0.21             0.755
# 1133                  5.82                         0.07             0.686
# 1134                  5.56                         0.06             0.684
# 1135                  5.86                         0.07             0.691
# 1136                  5.97                         0.06             0.692
# 1147                 10.90                         0.04             0.847
# 1148                 11.30                         0.45             0.888
# 1622                  9.01                         0.09             0.847
# 1623                  9.34                         0.09             0.841
# 1676                 12.10                         0.76             0.723
# 1866                  8.13                         0.02             0.701
# 1869                  9.41                         0.05             0.703
#
#       Health index  Income index  Educational index
# 374          0.950         0.921               0.779
# 494          0.934         0.982               0.967
# 588          0.708         0.724               0.753
# 589          0.749         0.569               0.700
# 590          0.729         0.565               0.726
# 591          0.725         0.660               0.736
# 592          0.739         0.645               0.724
# 593          0.735         0.717               0.797
# 594          0.717         0.592               0.716
# 595          0.742         0.730               0.828
# 596          0.726         0.675               0.741
# 597          0.748         0.653               0.783
# 616          0.944         0.840               0.750
# 622          0.950         0.857               0.766
# 630          0.933         0.846               0.739
# 635          0.726         0.812               0.681
# 924          0.986         0.956               0.742
# 965          0.796         0.849               0.903
# 982          0.827         0.700               0.759
# 983          0.801         0.705               0.720
# 984          0.822         0.686               0.749
# 985          0.816         0.697               0.784
# 986          0.768         0.696               0.757
# 987          0.813         0.708               0.782
# 988          0.787         0.696               0.696
# 994          0.774         0.524               0.667
# 997          0.809         0.507               0.694
# 998          0.766         0.502               0.739
# 1000         0.778         0.504               0.698
# 1023         0.869         0.807               0.872
# 1131         0.906         0.712               0.481
# 1132         0.897         0.753               0.637
# 1133         0.898         0.713               0.505
# 1134         0.919         0.713               0.488
# 1135         0.896         0.720               0.511
# 1136         0.906         0.716               0.510
# 1147         0.960         0.804               0.787
# 1148         0.960         0.889               0.820
# 1622         0.944         0.850               0.757
# 1623         0.941         0.836               0.756
# 1676         0.836         0.612               0.740
# 1866         0.811         0.617               0.687
# 1869         0.769         0.657               0.689

# %% [markdown]
# Dropping these 43 subnational observations is unfortunate. Unfortunately, without a way to match them to an administrative polygon there is little we can do.

# %% [markdown]
# ### Now let's see if there is any data in the shapefile that is missing from the tabular data

# %%
print("Shape file obs that don't match tabular data")

gpdf[~gpdf.GDLcode.isin(df.GDLCODE)]
# Out:
# Shape file obs that don't match tabular data
#       GDLcode constant iso_code country                    region      shdi  \
# 1069     MLTt    World      MLT    None                      None       NaN
# 1146       NA    World     None    None                      None       NaN
# 1487  SYRr101    World      SYR   Syria                  Damascus  0.702796
# 1488  SYRr102    World      SYR   Syria            Rural Damascus  0.656747
# 1489  SYRr103    World      SYR   Syria                      Homs  0.664678
# 1490  SYRr104    World      SYR   Syria                     Hamaa  0.649091
# 1491  SYRr105    World      SYR   Syria                   Tartous  0.684428
# 1492  SYRr106    World      SYR   Syria                Al Latakia  0.688736
# 1493  SYRr107    World      SYR   Syria               Edlab Idleb  0.613406
# 1494  SYRr108    World      SYR   Syria            Halab - Aleppo  0.609183
# 1495  SYRr109    World      SYR   Syria             Al Raka-Raqqa  0.581284
# 1496  SYRr110    World      SYR   Syria  Der El Zour - Deir Ezzor  0.615545
# 1497  SYRr111    World      SYR   Syria                 Al Hasaka  0.591597
# 1498  SYRr112    World      SYR   Syria         Al Swida - Sweida  0.695994
# 1499  SYRr113    World      SYR   Syria                     Daraa  0.650681
# 1500  SYRr114    World      SYR   Syria    Al Qunitara - Quneitra  0.636330
#
#                                                geometry
# 1069  MULTIPOLYGON (((14.41097 35.78847, 14.41097 35...
# 1146  MULTIPOLYGON (((169.12677 -52.61396, 169.12759...
# 1487  POLYGON ((36.40147 33.56197, 36.40089 33.51022...
# 1488  MULTIPOLYGON (((36.60928 33.18481, 36.60882 33...
# 1489  POLYGON ((39.96092 33.93422, 39.90065 33.90559...
# 1490  POLYGON ((36.30488 34.91472, 36.29511 34.91587...
# 1491  MULTIPOLYGON (((35.85986 34.85950, 35.85986 34...
# 1492  POLYGON ((35.94403 35.23540, 35.94373 35.23547...
# 1493  POLYGON ((37.09616 35.28223, 37.08421 35.28244...
# 1494  POLYGON ((37.77172 35.42765, 37.75378 35.42831...
# 1495  POLYGON ((39.29296 35.23827, 39.22988 35.24766...
# 1496  POLYGON ((39.96092 33.93422, 39.83850 34.09318...
# 1497  POLYGON ((41.32141 35.53627, 41.23705 35.54361...
# 1498  POLYGON ((36.55457 32.35205, 36.55273 32.37593...
# 1499  POLYGON ((36.17840 32.51831, 36.16471 32.52224...
# 1500  POLYGON ((35.90321 32.87455, 35.86902 32.90089...

# %% [markdown]
# This is just two countries. Less than ideal, but we can move on without them. The NA shape is a stange anomaly. It appears to contain small islands as well as North Korea and Taiwan.

# %%
n_dropped = len(nats_dropped) + len(subnats_dropped)

# %% [markdown]
# ## Let's go ahead and subset both of these files to the matching set of indices

# %%
df.set_index("GDLCODE", inplace=True)
gpdf.set_index("GDLcode", inplace=True)

# %%
matching_locs = df.index[df.index.isin(gpdf.index)]

# %%
df = df.loc[matching_locs]
gpdf = gpdf.loc[matching_locs]

# %%
df.to_pickle(out_directory + "/HDI_indicators_and_indices_clean.p")
gpdf.to_pickle(out_directory + "/HDI_ADM1_shapefile_clean.p")

# %% [markdown]
# #### Also write the national level data

# %%
nat_data = data[data["Level"] == "National"].set_index("ISO_Code")
nat_data.to_pickle(out_directory + "/HDI_indicators_and_indices_adm0_clean.p")

# %%
len(matching_locs)
# Out:
# 1729

# %%
print(round(n_dropped/(len(matching_locs ) + n_dropped),3) * 100, "% of HDI data dropped")
# Out:
# 2.6 % of HDI data dropped

# %% [markdown]
# ##  Transform shapefile to .01 x . 01 degree grid

# %% [markdown]
# This is the form needed for aggregating features in the existing pipeline

# %%
#dense_grid = get_dense_grid_for_gpdf_file(gpdf.reset_index(), columns=["GDLCODE", "iso_code","country"])

# %%
#dense_grid.head()

# %%
#outpath = data_dir + "/features/prepared_labels/GDL_HDI_polygon_coords_for_featurization.p"
#dense_grid["constant"] = 1
#dense_grid.to_pickle(outpath)
#dense_grid = pd.read_pickle(outpath)

# %%
#dense_grid.head()

# %% [markdown]
# Check to see if any polygon observations were dropped. This would occur if they are very small and don't overlay any grid centorids.

# %%
#len(dense_grid["GDLCODE"].unique()) != len(matching_locs)

# %% [markdown]
# None are dropped in this procedure
